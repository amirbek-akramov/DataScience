# %%
import pandas as pd
from pandas import DataFrame

# %%
data = {
    "Year": [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    "Population": [33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    "Temp": [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    Year  Population  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
# @title Year vs Temp

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Year']
  ys = series['Temp']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('Year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
_ = plt.ylabel('Temp')

# %%
df
# Out:
#    Year  Population  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#    Year  Population  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.shape
# Out:
# (8, 3)

# %%
df = DataFrame(data, columns=['Temp', 'Population', 'Year'])

# %%
df
# Out:
#    Temp  Population  Year
# 0  1.54        33.9  2021
# 1  1.48        33.5  2020
# 2  1.56        32.9  2019
# 3  1.62        32.5  2018
# 4  1.65        31.9  2017
# 5  1.66        31.4  2016
# 6  1.64        30.9  2015
# 7  1.53        28.5  2010

# %%
  df['Population']
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.4
# 6    30.9
# 7    28.5
# Name: Population, dtype: float64

# %%
df.Population = 0

# %%
df
# Out:
#    Temp  Population  Year
# 0  1.54           0  2021
# 1  1.48           0  2020
# 2  1.56           0  2019
# 3  1.62           0  2018
# 4  1.65           0  2017
# 5  1.66           0  2016
# 6  1.64           0  2015
# 7  1.53           0  2010

# %%
val = pd.Series([1700, 1650, 1300], index=[1, 8, 5])

# %%
val
# Out:
# 1    1700
# 8    1650
# 5    1300
# dtype: int64

# %%
df.Population = val

# %%
df
# Out:
#    Temp  Population  Year
# 0  1.54         NaN  2021
# 1  1.48      1700.0  2020
# 2  1.56         NaN  2019
# 3  1.62         NaN  2018
# 4  1.65         NaN  2017
# 5  1.66      1300.0  2016
# 6  1.64         NaN  2015
# 7  1.53         NaN  2010

# %%
data = {
    'Toyota': {'Camry': 25000, 'Corolla': 20000, 'Rav4': 30000},
    'Honda': {'Civic': 22000, 'Accord': 28000, 'CR-V': 32000},
    'Ford': {'Fusion': 24000, 'Escape': 28000, 'Explorer': 35000}
}

# %%
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#            Toyota    Honda     Ford
# Camry     25000.0      NaN      NaN
# Corolla   20000.0      NaN      NaN
# Rav4      30000.0      NaN      NaN
# Civic         NaN  22000.0      NaN
# Accord        NaN  28000.0      NaN
# CR-V          NaN  32000.0      NaN
# Fusion        NaN      NaN  24000.0
# Escape        NaN      NaN  28000.0
# Explorer      NaN      NaN  35000.0

# %%
df2
# Out:
#            Toyota    Honda     Ford
# Camry     25000.0      NaN      NaN
# Corolla   20000.0      NaN      NaN
# Rav4      30000.0      NaN      NaN
# Civic         NaN  22000.0      NaN
# Accord        NaN  28000.0      NaN
# CR-V          NaN  32000.0      NaN
# Fusion        NaN      NaN  24000.0
# Escape        NaN      NaN  28000.0
# Explorer      NaN      NaN  35000.0

# %%
arr = df2.values

# %%
arr
# Out:
# array([[25000.,    nan,    nan],
#        [20000.,    nan,    nan],
#        [30000.,    nan,    nan],
#        [   nan, 22000.,    nan],
#        [   nan, 28000.,    nan],
#        [   nan, 32000.,    nan],
#        [   nan,    nan, 24000.],
#        [   nan,    nan, 28000.],
#        [   nan,    nan, 35000.]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
df
# Out:
#    Temp  Population  Year
# 0  1.54         NaN  2021
# 1  1.48      1700.0  2020
# 2  1.56         NaN  2019
# 3  1.62         NaN  2018
# 4  1.65         NaN  2017
# 5  1.66      1300.0  2016
# 6  1.64         NaN  2015
# 7  1.53         NaN  2010

# %%
df2
# Out:
#            Toyota    Honda     Ford
# Camry     25000.0      NaN      NaN
# Corolla   20000.0      NaN      NaN
# Rav4      30000.0      NaN      NaN
# Civic         NaN  22000.0      NaN
# Accord        NaN  28000.0      NaN
# CR-V          NaN  32000.0      NaN
# Fusion        NaN      NaN  24000.0
# Escape        NaN      NaN  28000.0
# Explorer      NaN      NaN  35000.0

# %%
df2.index
# Out:
# Index(['Camry', 'Corolla', 'Rav4', 'Civic', 'Accord', 'CR-V', 'Fusion',
#        'Escape', 'Explorer'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Toyota', 'Honda', 'Ford'], dtype='object')

# %%
data = {
    'Brand': ['Toyota', 'Honda', 'Ford', 'Chevrolet', 'Tesla'],
    'Model': ['Camry', 'Civic', 'Mustang', 'Silverado', 'Model S'],
    'Year': [2019, 2020, 2021, 2018, 2022],
    'Mileage': [30000, 25000, 15000, 40000, 10000],
    'Price': [25000, 22000, 35000, 40000, 75000]
}
df3 = DataFrame(data)

# %%
df3
# Out:
#        Brand      Model  Year  Mileage  Price
# 0     Toyota      Camry  2019    30000  25000
# 1      Honda      Civic  2020    25000  22000
# 2       Ford    Mustang  2021    15000  35000
# 3  Chevrolet  Silverado  2018    40000  40000
# 4      Tesla    Model S  2022    10000  75000

# %%
columns = df3.columns

# %%
columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Mileage', 'Price'], dtype='object')

# %%
"Brand" in columns
# Out:
# True

# %%
columns[0]
# Out:
# 'Brand'

# %%
columns[0] = "Bra"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7f23c952f9d9> in <cell line: 1>()
# ----> 1 columns[0] = "Bra"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5300     @final
#    5301     def __setitem__(self, key, value):
# -> 5302         raise TypeError("Index does not support mutable operations")
#    5303
#    5304     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
df3
# Out:
#        Brand      Model  Year  Mileage  Price
# 0     Toyota      Camry  2019    30000  25000
# 1      Honda      Civic  2020    25000  22000
# 2       Ford    Mustang  2021    15000  35000
# 3  Chevrolet  Silverado  2018    40000  40000
# 4      Tesla    Model S  2022    10000  75000

# %%
df
# Out:
#    Temp  Population  Year
# 0  1.54         NaN  2021
# 1  1.48      1700.0  2020
# 2  1.56         NaN  2019
# 3  1.62         NaN  2018
# 4  1.65         NaN  2017
# 5  1.66      1300.0  2016
# 6  1.64         NaN  2015
# 7  1.53         NaN  2010

# %%
df2
# Out:
#            Toyota    Honda     Ford
# Camry     25000.0      NaN      NaN
# Corolla   20000.0      NaN      NaN
# Rav4      30000.0      NaN      NaN
# Civic         NaN  22000.0      NaN
# Accord        NaN  28000.0      NaN
# CR-V          NaN  32000.0      NaN
# Fusion        NaN      NaN  24000.0
# Escape        NaN      NaN  28000.0
# Explorer      NaN      NaN  35000.0

# %%
df2.index
# Out:
# Index(['Camry', 'Corolla', 'Rav4', 'Civic', 'Accord', 'CR-V', 'Fusion',
#        'Escape', 'Explorer'],
#       dtype='object')

# %%
arr = ['Camry', 'Corolla', 'Rav4', 'Civic', 'Accord', 'CR-V', 'Fusion',
       'Escape', 'Explorer']

# %%
arr[0]
# Out:
# 'Camry'

# %%
arr[1]
# Out:
# 'Corolla'

# %%
data2 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 22, 35, 28],
    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago', 'Seattle'],
    'Salary': [60000, 80000, 55000, 90000, 70000]
}

# %%
df2.append(pd.DataFrame(data2))
# Out:
# <ipython-input-45-4db815ea3001>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2.append(pd.DataFrame(data2))
#            Toyota    Honda     Ford     Name   Age           City   Salary
# Camry     25000.0      NaN      NaN      NaN   NaN            NaN      NaN
# Corolla   20000.0      NaN      NaN      NaN   NaN            NaN      NaN
# Rav4      30000.0      NaN      NaN      NaN   NaN            NaN      NaN
# Civic         NaN  22000.0      NaN      NaN   NaN            NaN      NaN
# Accord        NaN  28000.0      NaN      NaN   NaN            NaN      NaN
# CR-V          NaN  32000.0      NaN      NaN   NaN            NaN      NaN
# Fusion        NaN      NaN  24000.0      NaN   NaN            NaN      NaN
# Escape        NaN      NaN  28000.0      NaN   NaN            NaN      NaN
# Explorer      NaN      NaN  35000.0      NaN   NaN            NaN      NaN
# 0             NaN      NaN      NaN    Alice  25.0       New York  60000.0
# 1             NaN      NaN      NaN      Bob  30.0  San Francisco  80000.0
# 2             NaN      NaN      NaN  Charlie  22.0    Los Angeles  55000.0
# 3             NaN      NaN      NaN    David  35.0        Chicago  90000.0
# 4             NaN      NaN      NaN      Eva  28.0        Seattle  70000.0

# %%
data = {
    "email": ['ami@example.com', 'ant@example.com', 'joh@example.com', 'emi@example.com', 'sop@example.com', 'dav@example.com', 'oli@example.com', 'lia@example.com', 'emm@example.com', 'mat@example.com'],
    "age": [29, 42, 55, 23, 31, 46, 38, 49, 20, 27],
    "first_name": ['John', 'Emily', 'Michael', 'Sophia', 'Daniel', 'Jessica', 'Brian', 'Olivia', 'Matthew', 'Isabella'],
    "last_name": ['Smith', 'Johnson', 'Williams', 'Brown', 'Jones', 'Miller', 'Davis', 'Garcia', 'Rodriguez', 'Martinez']
}

dfe = pd.DataFrame(data, index=['amirbek', 'anton', 'john', 'emily', 'sophia', 'david', 'olivia', 'liam', 'emma', 'matthew'])

# %%
dfe
# Out:
#                    email  age first_name  last_name
# amirbek  ami@example.com   29       John      Smith
# anton    ant@example.com   42      Emily    Johnson
# john     joh@example.com   55    Michael   Williams
# emily    emi@example.com   23     Sophia      Brown
# sophia   sop@example.com   31     Daniel      Jones
# david    dav@example.com   46    Jessica     Miller
# olivia   oli@example.com   38      Brian      Davis
# liam     lia@example.com   49     Olivia     Garcia
# emma     emm@example.com   20    Matthew  Rodriguez
# matthew  mat@example.com   27   Isabella   Martinez

# %%
data2 = {
    "email":{"anton": "anto@example.com"},
    "age": {'anton':14},
    'first_name':{"anton":'antonello'},
    'last_name':{"anton":'antonello'}
}

# %%
dfe = dfe.append(pd.DataFrame(data2))
# Out:
# <ipython-input-55-d99733e77c11>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfe = dfe.append(pd.DataFrame(data2))

# %%
dfe
# Out:
#                     email  age first_name  last_name
# amirbek   ami@example.com   29       John      Smith
# anton     ant@example.com   42      Emily    Johnson
# john      joh@example.com   55    Michael   Williams
# emily     emi@example.com   23     Sophia      Brown
# sophia    sop@example.com   31     Daniel      Jones
# david     dav@example.com   46    Jessica     Miller
# olivia    oli@example.com   38      Brian      Davis
# liam      lia@example.com   49     Olivia     Garcia
# emma      emm@example.com   20    Matthew  Rodriguez
# matthew   mat@example.com   27   Isabella   Martinez
# anton    anto@example.com   14  antonello  antonello

# %%
newind = pd.Index(['emily', 'maverick', 'emma'])
newind
# Out:
# Index(['emily', 'maverick', 'emma'], dtype='object')

# %%
newind.isin(dfe.index)
# Out:
# array([ True, False,  True])

# %%
dfe.index.difference(newind)
# Out:
# Index(['amirbek', 'anton', 'david', 'john', 'liam', 'matthew', 'olivia',
#        'sophia'],
#       dtype='object')

# %%
newind.difference(dfe.index)
# Out:
# Index(['maverick'], dtype='object')

# %%
dfe.index.union(newind)
# Out:
# Index(['amirbek', 'anton', 'anton', 'david', 'emily', 'emma', 'john', 'liam',
#        'matthew', 'maverick', 'olivia', 'sophia'],
#       dtype='object')

# %%
dfe.index.delete(0)
# Out:
# Index(['anton', 'john', 'emily', 'sophia', 'david', 'olivia', 'liam', 'emma',
#        'matthew', 'anton'],
#       dtype='object')

# %%
dfe
# Out:
#                     email  age first_name  last_name
# amirbek   ami@example.com   29       John      Smith
# anton     ant@example.com   42      Emily    Johnson
# john      joh@example.com   55    Michael   Williams
# emily     emi@example.com   23     Sophia      Brown
# sophia    sop@example.com   31     Daniel      Jones
# david     dav@example.com   46    Jessica     Miller
# olivia    oli@example.com   38      Brian      Davis
# liam      lia@example.com   49     Olivia     Garcia
# emma      emm@example.com   20    Matthew  Rodriguez
# matthew   mat@example.com   27   Isabella   Martinez
# anton    anto@example.com   14  antonello  antonello
