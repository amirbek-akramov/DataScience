# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **pandas** Obyekti elementlariga *Funksiyalarni* qo'llash

# %%
df = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.537687 -0.679094  0.623618  0.138310
# b  0.325243 -0.833124 -1.277956  0.796685
# c  0.856796 -1.755933 -0.709758  0.653865

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.537687  0.679094  0.623618  0.138310
# b  0.325243  0.833124  1.277956  0.796685
# c  0.856796  1.755933  0.709758  0.653865

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0  -1.0    1.0    0.0
# b   0.0  -1.0   -1.0    1.0
# c   1.0  -2.0   -1.0    1.0

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.537687 -0.679094  0.623618  0.138310
# b  0.325243 -0.833124 -1.277956  0.796685
# c  0.856796 -1.755933 -0.709758  0.653865

# %%
df.mean()
# Out:
# Olma     0.573242
# Anor    -1.089384
# Qovun   -0.454699
# Anjir    0.529620
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a    0.155130
# b   -0.247288
# c   -0.238757
# dtype: float64

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.537687  0.679094  0.623618  0.138310
# b  0.325243  0.833124  1.277956  0.796685
# c  0.856796  1.755933  0.709758  0.653865

# %%
f = lambda x:x.max() - x.min()
df.apply(f)
# Out:
# Olma     0.531553
# Anor     1.076839
# Qovun    1.901575
# Anjir    0.658375
# dtype: float64

# %%
df.apply(lambda x:x.max() - x.min())
# Out:
# Olma     0.531553
# Anor     1.076839
# Qovun    1.901575
# Anjir    0.658375
# dtype: float64

# %%
def foo(x):
  return pd.Series([x.min(), x.max()], index=["min", "max"])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min  0.325243 -1.755933 -1.277956  0.138310
# max  0.856796 -0.679094  0.623618  0.796685

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(lambda X: X-2*180/x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-88952d15c709> in <cell line: 1>()
# ----> 1 df.applymap(lambda X: X-2*180/x)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in applymap(self, func, na_action, **kwargs)
#    9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
# -> 9653         return self.apply(infer).__finalize__(self, "applymap")
#    9654
#    9655     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in infer(x)
#    9649             if x.empty:
#    9650                 return lib.map_infer(x, func, ignore_na=ignore_na)
# -> 9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
#    9653         return self.apply(infer).__finalize__(self, "applymap")
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-30-88952d15c709> in <lambda>(X)
# ----> 1 df.applymap(lambda X: X-2*180/x)
#
# NameError: name 'x' is not defined
