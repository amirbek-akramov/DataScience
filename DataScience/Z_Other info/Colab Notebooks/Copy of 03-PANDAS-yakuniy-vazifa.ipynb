# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]

# %%
#@title To'g'ri javob
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 223             Guyana      3.6765      9.5220    790.326   214969
# 224      French Guiana      3.6685      9.5015    306.448    83534
# 225           Suriname      3.6125      9.3564    591.800   163820
# 226          Australia      3.3526      8.6832  25788.215  7692024
# 227            Iceland      3.3335      8.6338    343.353   103000
# 228            Namibia      3.1338      8.1166   2587.344   825615
# 229     Western Sahara      2.3003      5.9577    611.875   266000
# 230           Mongolia      2.1286      5.5129   3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517      3.533    12173
# 232          Greenland      0.0263      0.0680     56.877  2166086

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
print("Index 10:",df.iloc[10])
print("Index 50:",df.iloc[50])
print("Index 100:",df.iloc[100])
print("Index 200:",df.iloc[200])
# Out:
# Index 10: davlat        Bangladesh
# zichlik_km     1126.9465
# zichlik_mi     2918.7915
# aholi         166303.498
# maydoni           147570
# rank               139.0
# Name: 11, dtype: object
# Index 50: davlat        Trinidad and Tobago
# zichlik_km               273.5624
# zichlik_mi               708.5266
# aholi                    1403.375
# maydoni                      5130
# rank                         61.0
# Name: 51, dtype: object
# Index 100: davlat           Benin
# zichlik_km     110.556
# zichlik_mi    286.3401
# aholi         12451.04
# maydoni         112622
# rank             131.0
# Name: 101, dtype: object
# Index 200: davlat        Paraguay
# zichlik_km     17.7495
# zichlik_mi     45.9712
# aholi         7219.638
# maydoni         406752
# rank             173.0
# Name: 201, dtype: object

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
# JAVOBNI SHUYERGA YOZING
countries = [' Uzbekistan', " Hong-Kong", " Antartica"]
df.davlat.isin(countries)
# Out:
# rank
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# Name: davlat, Length: 232, dtype: bool

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
# JAVOBNI SHUYERGA YOZING
# df = df.set_index(df.davlat)
# df
# ______________
# df.drop(columns='davlat')
# ______________
df.sort_values(by='davlat')
# Out:
#                  davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 149         Afghanistan     61.0757    158.1862  39835.428   652230
# 111             Albania     99.9351    258.8318   2872.933    28748
# 198             Algeria     18.7328     48.5179  44616.624  2381741
# 50       American Samoa    276.8844    717.1307     55.100      199
# 78              Andorra    165.2885    428.0971     77.355      468
# ...                 ...         ...         ...        ...      ...
# 131   Wallis and Futuna     78.1268    202.3483     11.094      142
# 229      Western Sahara      2.3003      5.9577    611.875   266000
# 151               Yemen     57.7509    149.5749  30490.640   527968
# 188              Zambia     25.1400     65.1125  18920.651   752612
# 173            Zimbabwe     38.6229    100.0333  15092.171   390757
#
# [232 rows x 5 columns]

# %%
#@title Kutilayotgan natija

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
# JAVOBNI SHUYERGA YOZING
countries = ['Uzbekistan', 'Malaysia', 'South Korea', 'France']
df2 = df[df.davlat.isin(countries)]
df2 = df2.loc[:, ['davlat', 'aholi', 'maydoni']]
df2
# Out:
#            davlat      aholi  maydoni
# rank
# 23    South Korea  51305.186   100210
# 95         France  65426.179   551695
# 113      Malaysia  32776.194   330803
# 133    Uzbekistan  33935.763   447400

# %%
#@title O'xshash natija (boshqa davlatlar uchun)

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
# JAVOBNI SHUYERGA YOZING
df['aholi']*1000
# Out:
# rank
# 1       658394.0
# 2        39511.0
# 3      5896686.0
# 4      7552810.0
# 5        33698.0
#          ...
# 228    2587344.0
# 229     611875.0
# 230    3329289.0
# 231       3533.0
# 232      56877.0
# Name: aholi, Length: 232, dtype: float64

# %%
#@title Kutilgan natija

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.sort_values(by='aholi', ascending=False).tail(10)
# Out:
#                          davlat  zichlik_km  zichlik_mi   aholi  maydoni
# rank
# 27                       Tuvalu    458.8846   1188.5112  11.931       26
# 131           Wallis and Futuna     78.1268    202.3483  11.094      142
# 22                        Nauru    517.9048   1341.3733  10.876       21
# 26             Saint Barthelemy    471.7619   1221.8633   9.907       21
# 191   Saint Pierre and Miquelon     23.8264     61.7105   5.766      242
# 161                  Montserrat     48.7941    126.3768   4.977      102
# 231            Falkland Islands      0.2902      0.7517   3.533    12173
# 218                        Niue      6.2269     16.1277   1.619      260
# 98                      Tokelau    114.4167    296.3392   1.373       12
# 13                 Vatican City    800.0000   2072.0000   0.800        1

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
# JAVOBNI SHUYERGA YOZING
df['rank'] = df['maydoni'].rank()
df
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni   rank
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30    8.0
# 2               Monaco  19755.5000  51166.7450    39.511        2    2.0
# 3            Singapore   8305.1915  21510.4461  5896.686      710   43.0
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104   50.0
# 5            Gibraltar   5616.3333  14546.3033    33.698        6    3.0
# ...                ...         ...         ...       ...      ...    ...
# 228            Namibia      3.1338      8.1166  2587.344   825615  198.0
# 229     Western Sahara      2.3003      5.9577   611.875   266000  155.0
# 230           Mongolia      2.1286      5.5129  3329.289  1564110  214.0
# 231   Falkland Islands      0.2902      0.7517     3.533    12173   70.0
# 232          Greenland      0.0263      0.0680    56.877  2166086  221.0
#
# [232 rows x 6 columns]

# %%
#@title Kutilgan natija

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
countries = ['Uzbekistan', 'United Kingdom', 'Indonesia']
df[df.davlat.isin(countries)][['aholi']]
# Out:
#            aholi
# rank
# 49     68207.116
# 83    276361.783
# 133    33935.763

# %%
#@title O'xshash natija (boshqa davlatlar uchun)

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
# JAVOBNI SHUYERGA YOZING
df.sort_values(by='davlat')
# Out:
#                  davlat  zichlik_km  zichlik_mi      aholi  maydoni   rank
# rank
# 149         Afghanistan     61.0757    158.1862  39835.428   652230  192.0
# 111             Albania     99.9351    258.8318   2872.933    28748   89.0
# 198             Algeria     18.7328     48.5179  44616.624  2381741  223.0
# 50       American Samoa    276.8844    717.1307     55.100      199   20.0
# 78              Andorra    165.2885    428.0971     77.355      468   38.0
# ...                 ...         ...         ...        ...      ...    ...
# 131   Wallis and Futuna     78.1268    202.3483     11.094      142   15.0
# 229      Western Sahara      2.3003      5.9577    611.875   266000  155.0
# 151               Yemen     57.7509    149.5749  30490.640   527968  183.0
# 188              Zambia     25.1400     65.1125  18920.651   752612  194.0
# 173            Zimbabwe     38.6229    100.0333  15092.171   390757  172.0
#
# [232 rows x 6 columns]

# %%
#@title Kutilgan natija

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
print("10 o'rin:", df.iloc[10])
print("50 o'rin:", df.iloc[50])
print("100 o'rin:", df.iloc[100])
print("200 o'rin:", df.iloc[200])
# Out:
# 10 o'rin: davlat        Bangladesh
# zichlik_km     1126.9465
# zichlik_mi     2918.7915
# aholi         166303.498
# maydoni           147570
# rank               139.0
# Name: 11, dtype: object
# 50 o'rin: davlat        Trinidad and Tobago
# zichlik_km               273.5624
# zichlik_mi               708.5266
# aholi                    1403.375
# maydoni                      5130
# rank                         61.0
# Name: 51, dtype: object
# 100 o'rin: davlat           Benin
# zichlik_km     110.556
# zichlik_mi    286.3401
# aholi         12451.04
# maydoni         112622
# rank             131.0
# Name: 101, dtype: object
# 200 o'rin: davlat        Paraguay
# zichlik_km     17.7495
# zichlik_mi     45.9712
# aholi         7219.638
# maydoni         406752
# rank             173.0
# Name: 201, dtype: object

# %%
#@title O'xshash natija (boshqa qatorlar uchun)

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
df[df.davlat.isin(['Malaysia', 'Nigeria', 'Nepal', 'Italy', 'Uzbekistan'])].values
# Out:
# array([['Nigeria', 228.8461, 592.7114, 211400.708, 923768, 201.0],
#        ['Nepal', 201.6219, 522.2008, 29674.92, 147181, 138.0],
#        ['Italy', 200.3328, 518.8619, 60367.477, 301336, 160.0],
#        ['Malaysia', 99.0807, 256.619, 32776.194, 330803, 165.0],
#        ['Uzbekistan', 75.8511, 196.4542, 33935.763, 447400, 176.0]],
#       dtype=object)

# %%
df.iloc[10]
# Out:
# davlat        Bangladesh
# zichlik_km     1126.9465
# zichlik_mi     2918.7915
# aholi         166303.498
# maydoni           147570
# rank               139.0
# Name: 11, dtype: object

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
