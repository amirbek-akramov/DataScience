# %%
import pandas as pd
import numpy as np

# %% [markdown]
# `pandas` kutubxonasi fayllar bilan ishlaydigan bir nechta funksiyalardan iborat.
#
# `read_csv` vergul bilan ajratilgan jadval fayllarni o'qish uchun
#
# `read` table probel (bo'sh joy) bilan ajratilgan jadval fayllarni o'qish uchun
#
# `read_excel` xls yoki xlsx formatidagi Excel fayllarni o'qish uchun
#
# `read_clipboard` ko'chirilgan (xotiradagi) jadvalni o'qish
#
# `read_hdf` HDFS formatidagi fayllarni o'qish
#
# `read_html` HTML (web) sahifadagi barcha jadvallarni o'qish
#
# `read_json` JSON ma'lumotlarni o'qish
#
# `read_pickle` pickle formatidagi fayllarni o'qish
# -
#
# `read_sql` - SQL query dan qaytgan ma'lumotlarni o'qish (SQLAlchemy bilan ishlaydi)

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Out:
# --2024-03-22 04:08:23--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv.3’
#
# merc.csv.3          100%[===================>] 710.98K  --.-KB/s    in 0.05s
#
# 2024-03-22 04:08:23 (15.4 MB/s) - ‘merc.csv.3’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets/
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
pd.read_csv("merc.csv")
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
df = pd.read_csv("merc.csv")
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df2 = pd.read_csv("sample_data/california_housing_train.csv")
df2.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df3 = pd.read_excel('uzbekistan.xlsx')
df3.head()
# Out:
#           Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0   Andijon viloyati             4200  1899000
# 1    Buxoro viloyati            39400  1384700
# 2  Fargʻona viloyati             6800  2597000
# 3    Jizzax viloyati            20500   910500
# 4    Xorazm viloyati             6300  1200000

# %%
df4 = pd.read_excel('uzbekistan.xlsx', index_col=0, names=['hudud', 'maydon', 'aholi'])
df4.head()
# Out:
#                    maydon    aholi
# hudud
# Andijon viloyati     4200  1899000
# Buxoro viloyati     39400  1384700
# Fargʻona viloyati    6800  2597000
# Jizzax viloyati     20500   910500
# Xorazm viloyati      6300  1200000

# %%
df4 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv", index_col="index", nrows=15)
df4
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
df5 = pd.read_excel("uzbekistan.xlsx", index_col=0, names=['hudud', 'maydon', 'aholi'])
df5
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df.to_csv("newuz.csv")

# %%
pd.read_csv("newuz.csv")
# Out:
#        Unnamed: 0       model  year  price transmission  mileage fuelType  \
# 0               0         SLK  2005   5200    Automatic    63000   Petrol
# 1               1     S Class  2017  34948    Automatic    27000   Hybrid
# 2               2    SL CLASS  2016  49948    Automatic     6200   Petrol
# 3               3     G Class  2016  61948    Automatic    16000   Petrol
# 4               4     G Class  2016  73948    Automatic     4000   Petrol
# ...           ...         ...   ...    ...          ...      ...      ...
# 13114       13114     C Class  2020  35999    Automatic      500   Diesel
# 13115       13115     B Class  2020  24699    Automatic     2500   Diesel
# 13116       13116   GLC Class  2019  30999    Automatic    11612   Diesel
# 13117       13117   CLS Class  2019  37990    Automatic     2426   Diesel
# 13118       13118     S Class  2019  54999    Automatic     2075   Diesel
#
#        tax   mpg  engineSize
# 0      325  32.1         1.8
# ...

# %%
obj = df5.maydon
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_csv("uzmaydon.csv")

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv
# Out:
# --2024-03-22 04:08:24--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3146 (3.1K) [text/plain]
# Saving to: ‘automobile_data.csv.2’
#
# automobile_data.csv 100%[===================>]   3.07K  --.-KB/s    in 0s
#
# 2024-03-22 04:08:24 (52.3 MB/s) - ‘automobile_data.csv.2’ saved [3146/3146]

# %%
pd.read_csv("uzmaydon.csv")
# Out:
#                             hudud  maydon
# 0                Andijon viloyati    4200
# 1                 Buxoro viloyati   39400
# 2               Fargʻona viloyati    6800
# 3                 Jizzax viloyati   20500
# 4                 Xorazm viloyati    6300
# 5               Namangan viloyati    7900
# 6                 Navoiy viloyati  110800
# 7            Qashqadaryo viloyati   28400
# 8   Qoraqalpogʻiston Respublikasi  160000
# 9              Samarqand viloyati   16400
# 10              Sirdaryo viloyati    5100
# 11           Surxondaryo viloyati   20800
# 12              Toshkent viloyati   15300

# %%
pd.read_csv("uzmaydon.csv", squeeze=True, index_col=0)
# Out:
# <ipython-input-115-4367c689d1be>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv("uzmaydon.csv", squeeze=True, index_col=0)
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
df6 = pd.read_csv('automobile_data.csv', index_col=0)
df6
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
df6.to_excel("drive/MyDrive/newcars.xlsx", index=False)

# %%
#@title HDF5 formatting
hdfobj = pd.HDFStore("data.h5")
df6.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
hdfobj.put('uzdata', df5)

# %%
hdfobj.put('cardata', df6)

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdfobj['uzdata']
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
hdfobj.close()

# %%
hdfobj = pd.HDFStore("data.h5")

# %%
hdfobj.close()

# %%
#@title Read from Websites
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(tashkent)
# Out:
# 19

# %%
tashkent[0]
# Out:
#                             Tashkent  ТошкентToshkent  \
# 0                                        Capital city
# 1   .mw-parser-output .tmulti .multiimageinner{dis...
# 2   .mw-parser-output .ib-settlement-cols{text-ali...
# 3                             Nickname: Tash (A rock)
# 4   Motto(s): Kuch Adolatdadir ("Strength is in Ju...
# 5                  Location of Tashkent in Uzbekistan
# 6   .mw-parser-output .locmap .od{position:absolut...
# 7   Coordinates: .mw-parser-output .geo-default,.m...
# 8                                             Country
# 9                                             Settled
# 10                                          Divisions
# 11                                         Government
# 12                                             • Type
# 13                                    • Hakim (Mayor)
# 14                                               Area
# 15                                     • Capital city
# ...

# %%
tashkent[5]
# Out:
#    Climate data for Tashkent (1991–2020, extremes 1867–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                          Mean daily maximum °C (°F)
# 2                                  Daily mean °C (°F)
# 3                          Mean daily minimum °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6              Average extreme snow depth cm (inches)
# 7                                  Average rainy days
# 8                                  Average snowy days
# 9                       Average relative humidity (%)
# 10                        Mean monthly sunshine hours
# 11                        Source 1: Pogoda.ru.net[54]
# 12                                 Source 2: NOAA[55]
#
#                                                               \
#                             Jan                          Feb
# ...

# %%
tashkent[11]
# Out:
#     Nr       District  Population (2021)[4]  Area (km2)[67][66]  \
# 0    1       Bektemir                 31400               17.83
# 1    2      Chilanzar                260700               29.94
# 2    3      Yashnobod                258800               33.70
# 3    4        Mirobod                142800               17.10
# 4    5  Mirzo Ulugbek                285000               35.15
# 5    6        Sergeli                105700               37.36
# 6    7   Shayxontoxur                348300               29.70
# 7    8        Olmazor                377100               34.50
# 8    9        Uchtepa                278200               24.00
# 9   10     Yakkasaray                121600               14.60
# 10  11      Yunusabad                352000               40.60
# 11  12     Yangihayot                132800               44.20
#
#     Density (area/km2)  Map
# 0                 1761  NaN
# 1                 8707  NaN
# 2                 7680  NaN
# ...

# %%
#@title From API or JSON
pd.read_json("sample_data/anscombe.json")
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13
# 20     II   7   7.26
# 21     II   5   4.74
# 22    III  10   7.46
# 23    III   8   6.77
# 24    III  13  12.74
# 25    III   9   7.11
# 26    III  11   7.81
# 27    III  14   8.84
# 28    III   6   6.08
# 29    III   4   5.39
# 30    III  12   8.15
# 31    III   7   6.42
# 32    III   5   5.73
# 33     IV   8   6.58
# 34     IV   8   5.76
# 35     IV   8   7.71
# 36     IV   8   8.84
# 37     IV   8   8.47
# 38     IV   8   7.04
# 39     IV   8   5.25
# 40     IV  19  12.50
# 41     IV   8   5.56
# ...

# %%
pd.read_json("https://openlibrary.org/subjects/python.json?published_in=2010-2024")
# Out:
#                  key    name subject_type  work_count  \
# 0   /subjects/python  python      subject         110
# 1   /subjects/python  python      subject         110
# 2   /subjects/python  python      subject         110
# 3   /subjects/python  python      subject         110
# 4   /subjects/python  python      subject         110
# 5   /subjects/python  python      subject         110
# 6   /subjects/python  python      subject         110
# 7   /subjects/python  python      subject         110
# 8   /subjects/python  python      subject         110
# 9   /subjects/python  python      subject         110
# 10  /subjects/python  python      subject         110
# 11  /subjects/python  python      subject         110
#
#                                                 works
# 0   {'key': '/works/OL2784125W', 'title': 'Learnin...
# 1   {'key': '/works/OL2784127W', 'title': 'Python'...
# 2   {'key': '/works/OL16976951W', 'title': 'Think ...
# ...

# %%
import requests as rt
r = rt.get("https://openlibrary.org/search.json?q=the+lord+of+the+rings")
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'numFound': 847,
#  'start': 0,
#  'numFoundExact': True,
#  'docs': [{'author_alternative_name': ['Yue Han Luo Na De Rui Er Tuo Er Jin',
#     'J. R. R. Tolkien',
#     'John Ronald Reuel Tolkien',
#     'John R. R. Tolkien',
#     'Dzhon R. R. Tolkin',
#     'Tolkien'],
#    'author_key': ['OL26320A'],
#    'author_name': ['J.R.R. Tolkien'],
#    'contributor': ['Rob Inglis (Narrator)',
#     'Dramatization (Narrator)',
#     'Lee, Alan.',
#     'Tanaka, Akiko.',
#     'Lee, Alan, 1947-',
#     'Tolkien, J. R. R. 1892-1973.',
#     'Ian Holm (Narrator)',
#     'Brian Sibley (Narrator)',
#     'Rob Inglis (Narrator, Reader)',
#     'Kořínek, Otakar, 1946-',
#     'Seta, Teiji, 1916-'],
#    'cover_edition_key': 'OL21058613M',
#    'cover_i': 9255566,
#    'ddc': ['823.914', '823.91', '823.912'],
#    'ebook_access': 'borrowable',
#    'ebook_count_i': 17,
#    'edition_count': 159,
#    'edition_key': ['OL49215435M',
#     'OL43069225M',
#     'OL37015716M',
#     'OL31867423M',
# ...

# %%
pd.DataFrame(r.json())
# Out:
#     numFound  start  numFoundExact  \
# 0        847      0           True
# 1        847      0           True
# 2        847      0           True
# 3        847      0           True
# 4        847      0           True
# ..       ...    ...            ...
# 95       847      0           True
# 96       847      0           True
# 97       847      0           True
# 98       847      0           True
# 99       847      0           True
#
#                                                  docs  num_found  \
# 0   {'author_alternative_name': ['Yue Han Luo Na D...        847
# 1   {'author_alternative_name': ['John R. R. Tolki...        847
# 2   {'author_alternative_name': ['John R. R. Tolki...        847
# 3   {'author_alternative_name': ['John R. R. Tolki...        847
# 4   {'author_alternative_name': ['Yue Han Luo Na D...        847
# ..                                                ...        ...
# 95  {'key': '/works/OL6440558W', 'type': 'work', '...        847
# ...

# %%
pd.read_json('https://openlibrary.org/search.json?q=the+lord+of+the+rings')
# Out:
#     numFound  start  numFoundExact  \
# 0        847      0           True
# 1        847      0           True
# 2        847      0           True
# 3        847      0           True
# 4        847      0           True
# ..       ...    ...            ...
# 95       847      0           True
# 96       847      0           True
# 97       847      0           True
# 98       847      0           True
# 99       847      0           True
#
#                                                  docs  num_found  \
# 0   {'author_alternative_name': ['Yue Han Luo Na D...        847
# 1   {'author_alternative_name': ['John R. R. Tolki...        847
# 2   {'author_alternative_name': ['John R. R. Tolki...        847
# 3   {'author_alternative_name': ['John R. R. Tolki...        847
# 4   {'author_alternative_name': ['Yue Han Luo Na D...        847
# ..                                                ...        ...
# 95  {'key': '/works/OL6440558W', 'type': 'work', '...        847
# ...
