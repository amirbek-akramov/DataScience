# %% [markdown]
# # Pandas kutubxonasiga doir bilimlaringizni mustaxkamlash uchun mashqlar!
#
# Hurmatli o'quvchi, bilimingizni yanada mustaxkamlashingiz va chuqurroq ko'nikmalarga ega bo'lishingiz uchun sizga topshiriqlar tayyorladik. Sizga yengillik yaratish maqsadida topshiriqlarni `📌Mavzulashtirdik`

# %% [markdown]
# ## `📌Pandas kutubxonasini yuklash`
#
# **1.** Pandas kutubxonasini `pd` nomi ostida yuklang va pandas kutubxonasini chop eting.

# %%
import pandas as pd

# %% [markdown]
# **2.** Versiya va konfiguratsiyani tekshiring.

# %%
print("Versiyasi: ", pd.__version__)
print("Konfiguratsiyasi: ", pd.options)
# Out:
# Versiyasi:  1.5.3
# Konfiguratsiyasi:  <pandas._config.config.DictWrapper object at 0x7a89860804f0>

# %% [markdown]
# **3.** Pandas kutubxonasida mavjud bo'lgan barcha versiya ma'lumotlarini chop eting.

# %%
pd.show_versions()
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 2e218d10984e9919f0296931d92ea851c6a6faf5
# python           : 3.10.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 6.1.58+
# Version          : #1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.5.3
# numpy            : 1.25.2
# pytz             : 2023.4
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.1.2
# Cython           : 3.0.9
# pytest           : 7.4.4
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.4
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.9
# jinja2           : 3.1.3
# IPython          : 7.34.0
# pandas_datareader: 0.10.0
# bs4              : 4.12.3
# bottleneck       : None
# brotli           : None
# fastparquet      : None
# fsspec           : 2023.6.0
# gcsfs            : 2023.6.0
# matplotlib       : 3.7.1
# numba            : 0.58.1
# numexpr          : 2.9.0
# odfpy            : None
# openpyxl         : 3.1.2
# pandas_gbq       : 0.19.2
# pyarrow          : 14.0.2
# pyreadstat       : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.11.4
# snappy           : None
# sqlalchemy       : 2.0.28
# tables           : 3.8.0
# tabulate         : 0.9.0
# xarray           : 2023.7.0
# xlrd             : 2.0.1
# xlwt             : None
# zstandard        : None
# tzdata           : None

# %% [markdown]
# ## `📌DataFrame: Asoslar`
#
# DataFrames-da ma'lumotlarni tanlash(selecting), saralash(sorting), qo'shish(adding) va yig'ish(aggregating) uchun bir nechta asosiy mashqlar.
#
# 💡Eslatma: NumPy kutubxonasini import qilishni unutmang:
# ``` python
# import numpy as np
# ```
#
# Quyidagi Python lug'ati(dictionary) `data` va Python ro'yxati(list) `labels` ni ko'rib chiqing:
#
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```

# %% [markdown]
# **4.** Ushbu `lug'at`(dictionary) yordamida `data` dan `labels` indeksiga ega DataFrame yarating.

# %%
import numpy as np

data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **5.** Ushbu DataFrame va uning ma'lumotlari haqidagi asosiy ma'lumotlarning qisqacha mazmunini ko'rsating.
#
# `💡Ishora:` DataFrame-da chaqirilishi mumkin bo'lgan yagona usul mavjud.

# %%
df.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# **6.** DataFrame `df` dastlabki 3 qatorini qaytaring.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **7.** DataFrame `df`-dan faqat `animal` va `age` ustunlarini tanlang.

# %%
df[['animal', 'age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **8.** `[3, 4, 8]` va `['animal', 'age']` qatorlaridagi ma'lumotlarni tanlang.

# %%
df.iloc[[3, 4, 8], [0, 1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **9.** Faqat `visits` soni 3 tadan ko'p bo'lgan qatorlarni tanlang.

# %%
df[df.visits>=3]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %% [markdown]
# 10. Yosh yo'qolgan qatorlarni tanlang, ya'ni `NaN`

# %%
df[df.age.isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **11.** `animal` qatoridagi `cat` va `age` qatoridagi `3` dan kichik bo'lgan umumiy qatorlarni tanlang.

# %%
df[(df.animal=='cat') & (df.age<=3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no

# %% [markdown]
# **12.** `age` 2 va 4 (shu jumladan) orasidagi qatorlarni tanlang.

# %%
df[(df.age <= 4) & (df.age>=2)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **13.** `f` qatoridagi yoshni `1,5` ga o'zgartiring.

# %%
df.loc[['f'], ['age']] =1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** `df` yordamida `visits` qatorining yig'indisini hisoblang.

# %%
df.visits.sum()
# Out:
# 19

# %% [markdown]
# **15.** Har bir `animal` uchun o'rtacha yoshni `df` da hisoblang.

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **16.** `df` yordamida har bir turdagi `animal` sonini hisoblang.

# %%
df.animal.value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# **17.** `animal` ustunida, `snake` so'zini `python` so'ziga o'zgartiring.

# %%
df.loc[df['animal'] == 'snake', 'animal']='python'
df.loc[["c",'g']]
# Out:
#    animal  age  visits priority
# c  python  0.5       2       no
# g  python  4.5       1       no

# %% [markdown]
# ## `📌DataFrame: Murakkab`
#
# ### Bir oz qiyinroq: to'g'ri javob olish uchun ikki yoki undan ortiq usullarni birlashtirish kerak bo'lishi mumkin
#
# Oldingi bo'lim DataFrame-ning asosiy, ammo muhim operatsiyalari bo'yicha vazifalarni jamlagan edi. Quyida ma'lumotlarni kesishingiz kerak bo'lgan mashqlar mavjud.

# %% [markdown]
# **18.** Sizda butun sonlardan iborat `A` ustunli DataFrame `df` mavjud. Misol uchun:
# ```python
# df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
# ```
#
# Yuqoridagi qator bilan bir xil butun sonni o'z ichiga olgan qator yarating.
#
#
# 💡Sizda quyidagi qiymatlarni o'z ichiga olgan ustun paydo bo'lishi kerak:
#
# ```python
# 1, 2, 3, 4, 5, 6, 7
# ```

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
df.A.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# **19.** Raqamli qiymatlardan iborat DataFrame berildi
#
# ```python
# df = pd.DataFrame(np.random.random(size=(5, 3))) # float qiymatlarining 5x3 o'lchovi
# ```
#
# Qatordagi har bir elementdan satrning o'rtacha qiymatini qanday ayirish mumkin?

# %%
df = pd.DataFrame(np.random.random(size=(5, 3)))
df.mean()
# Out:
# 0    0.625095
# 1    0.636490
# 2    0.369605
# dtype: float64

# %% [markdown]
# **20.** Sizda 10 ta haqiqiy raqamlar ustunidan iborat DataFrame mavjud:
#
# ``` python
# df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
# ```
# Qaysi sonlar ustunining yig'indisi eng kichik ekanini hisoblang. U ustunning yorlig'ini qaytaring.

# %%
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
df[[df.sum().idxmin()]].sum()
# Out:
# f    1.479159
# dtype: float64

# %% [markdown]
# **21.** Quyida butun sonlardan iborat DataFrame `df` mavjud. Har bir satrga  5 ta yozuv `NaN` qiymatlari kiritilgan.
#
# DataFrame ning har bir qatori uchun uchinchi `NaN` qiymatini o'z ichiga olgan ustunni toping.
#
# Ustun yorliqlarini qaytarishingiz kerak: `e, c, d, h, d`

# %%
nan = np.nan

data = [[0.04,  nan,  nan, 0.25,  nan, 0.43, 0.71, 0.51,  nan,  nan],
        [ nan,  nan,  nan, 0.04, 0.76,  nan,  nan, 0.67, 0.76, 0.16],
        [ nan,  nan, 0.5 ,  nan, 0.31, 0.4 ,  nan,  nan, 0.24, 0.01],
        [0.49,  nan,  nan, 0.62, 0.73, 0.26, 0.85,  nan,  nan,  nan],
        [ nan,  nan, 0.41,  nan, 0.05,  nan, 0.61,  nan, 0.48, 0.68]]

columns = list('abcdefghij')

df = pd.DataFrame(data, columns=columns)
ustunlar_nan_soni = df.isnull().sum()
ustunlar_nan_soni = ustunlar_nan_soni.sort_values(ascending=False)
ustunlar = ustunlar_nan_soni.head(5)
ustunlar
# Out:
# b    5
# a    3
# c    3
# h    3
# d    2
# dtype: int64

# %% [markdown]
# **22.** DataFrame `grps` guruhlari ustuniga va `vals` butun qiymatlari ustuniga ega:
#
# ```python
# df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'),
#                    'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
# ```
# Har bir `grps` uchun uchta eng katta qiymatning yig‘indisini toping.
#
# 💡Javobni quyidagicha yakunlashingiz kerak:
# ```
# grps
# a    409
# b    156
# c    345
# ```

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'),
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})

df.groupby('grps')['vals'].nlargest(3).groupby(level=0).sum()
# Out:
# grps
# a    409
# b    156
# c    345
# Name: vals, dtype: int64

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **28.** Quyida tuzilgan DataFrame `df` ikkita butun son ustuniga ega 'A' va 'B'. "A" dagi qiymatlar 1 dan 100 gacha (shu jumladan).
#
# “A” dagi har bir 10 ta ketma-ket butun sonlar guruhi uchun (ya’ni `(0, 10]`, `(10, 20]`, ...) 'B' ustunidagi mos qiymatlar yig'indisini hisoblang.
#
# Javob quyidagicha bo'lishi kerak:
#
# ```
# A
# (0, 10]      635
# (10, 20]     360
# (20, 30]     315
# (30, 40]     306
# (40, 50]     750
# (50, 60]     284
# (60, 70]     424
# (70, 80]     526
# (80, 90]     835
# (90, 100]    852
# ```

# %%
df = pd.DataFrame(np.random.RandomState(8765).randint(1, 101, size=(100, 2)), columns = ["A", "B"])

bins = np.arange(0, 101, 10)
labels = [f'({i}, {i+10}]' for i in range(0, 100, 10)]
df['A_groups'] = pd.cut(df['A'], bins=bins, labels=labels, right=False)

# B ustunidagi qiymatlarni A guruhlari bo'yicha guruhlaymiz va ularga mos qiymatlarni hisoblaymiz
df.groupby('A_groups')['B'].sum()
# Out:
# A_groups
# (0, 10]      635
# (10, 20]     335
# (20, 30]     340
# (30, 40]     296
# (40, 50]     676
# (50, 60]     281
# (60, 70]     511
# (70, 80]     456
# (80, 90]     806
# (90, 100]    788
# Name: B, dtype: int64

# %% [markdown]
# **29.** 'X' butun son ustuni bo'lgan DataFrame:
# ```python
# df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
# ```
#
# Har bir qiymat uchun farqni oldingi nolga qaytaring.
#
# Sizda natija quyidagicha bo'lishi kerak:
#
# ```
# [1, 2, 0, 1, 2, 3, 4, 0, 1, 2]
# ```
#
# Buni yangi `Y` ustuni deb nomlang.

# %%
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
id = 0
df['X'] = [(id := id + 1) if num != 0 else (id := 0) for num in df['X']]

df['X'].tolist()
# Out:
# [1, 2, 0, 1, 2, 3, 4, 0, 1, 2]

# %% [markdown]
# ##`📌Ma'lumotlarni tozalash`
#
# Bu har doim sodir bo'ladi: kimdir sizga noto'g'ri tuzilgan satrlar, ro'yxatlar va yetishmayotgan ma'lumotlarni o'z ichiga olgan ma'lumotlarni beradi. Tahlilni davom ettirish uchun uni qanday tartibga keltirasiz?
#
# **30.** Quyidagi jumboqni tasavvur qilishi uchun ushbu misolni DataFrame sifatida oling:
#
# ```python
# df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',
#                                'Budapest_PaRis', 'Brussels_londOn'],
#               'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
#               'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
#                    'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
#                                '12. Air France', '"Swiss Air"']})
# ```
# Tartiblaganingizdan so'ng u quyidagi ko'rinishga ega bo'lishi kerak:
#
# ```
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
# ```

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
                               '12. Air France', '"Swiss Air"']})

df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# **31.** **FlightNumber** ustunidagi ba'zi qiymatlar yo'q. Ular `NaN` ko'rinishida yozilgan. Bu raqamlar har bir qatorda 10 ga ko'payishi kerak, shuning uchun 10055 va 10075 ni qo'yish kerak. Ushbu yetishmayotgan raqamlarni to'ldirish uchun `df` ni o'zgartiring va ustunni butun son ustuniga aylantiring.

# %%
df['FlightNumber'] = df['FlightNumber'].fillna(df['FlightNumber'].shift(1) + 10)

df['FlightNumber'] = df['FlightNumber'].astype(int)

print(df)
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# **32.** **From\_To** ustunini ikkita alohida ustun ko'rinishida yozing.
#
# To'g'ri qiymatlarga ega `temp` deb nomlangan yangi Temporary DataFrame berish uchun har bir satrni pastki chiziq chegarasiga ajrating.                                                                     Ushbu Temporary DataFrame ustunlarini `From` va `To` deb nomlang.

# %%
from_d = []
to_d = []
for ft in df.From_To:
  ft_splited = ft.replace("_", " ").split()
  from_d.append(ft_splited[0])
  to_d.append(ft_splited[1])
temp = pd.DataFrame({"From": from_d, 'To':to_d})
temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# **34.** Temporary DataFrame `temp` da shahar nomlari betartib yozilgan.Satrlarning faqat birinchi harfi katta yozilishi kerak.
#                                                                          (Masalan, "londON" "London" bo'lishi kerak.)

# %%
temp['From'] = temp['From'].str.capitalize()
temp['To'] = temp['To'].str.capitalize()
temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# **33**. `Airline` ustunida aviakompaniya nomlari atrofida qoʻshimcha tinish belgilari va belgilar paydo boʻlganini koʻrishingiz mumkin. Faqat aviakompaniya nomini qoldiring. Masalan, ʻ'(British Airways. )'' `British Airways` ko'rinishida yozilishi kerak.

# %%
df['Airline'] = df['Airline'].str.replace(r'[^\w\s]', '')
df
# Out:
# <ipython-input-184-fea21c5abb95>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Airline'] = df['Airline'].str.replace(r'[^\w\s]', '')
#             From_To  FlightNumber  RecentDelays           Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM
# 1      MAdrid_miLAN         10055            []     Air France 12
# 2  londON_StockhOlm         10065  [24, 43, 87]  British Airways
# 3    Budapest_PaRis         10075          [13]     12 Air France
# 4   Brussels_londOn         10085      [67, 32]         Swiss Air

# %% [markdown]
# **34.** `df` dan **From_To** ustunini o'chiring va Temporary DataFrame `temp` ustunini qo'shing.

# %%
temp['From_To'] = df.pop('From_To')
temp
# Out:
#        From         To           From_To
# 0    London      Paris      LoNDon_paris
# 1    Madrid      Milan      MAdrid_miLAN
# 2    London  Stockholm  londON_StockhOlm
# 3  Budapest      Paris    Budapest_PaRis
# 4  Brussels     London   Brussels_londOn

# %% [markdown]
# **34**. `RecentDelays` ustunida qiymatlar DataFrame-ga ro'yxat sifatida kiritilgan. Sizning vazifangiz birinchi qiymatni o'z ustunida, har bir ikkinchi qiymatni o'z ustunida va qolgan qiymatlar ham ustunga mos holda chop etish. Agar N-chi qiymat bo'lmasa, qiymat `NaN` deb nomlanishi kerak.
#
# Roʻyxatlar qatorini `delays` nomli DataFrame ichiga kengaytiring, `delay_1`, `delay_2` va qolgan ustunlarni ham nomlarini oʻzgartiring va `df` dagi keraksiz `RecentDelays` ustunini `delays` bilan almashtiring.

# %%
delays = df['RecentDelays'].apply(pd.Series)
delays.columns = [f'delay_{i+1}' for i in range(delays.shape[1])]

df = pd.concat([df.drop('RecentDelays', axis=1), delays], axis=1)
max_delay_cols = 3
for i in range(max_delay_cols):
    df[f'delay_{i+1}'] = df[f'delay_{i+1}'].fillna(np.nan)

print("DataFrame 'df' after restructuring 'RecentDelays':")
print(df)
# Out:
# DataFrame 'df' after restructuring 'RecentDelays':
#    FlightNumber           Airline  delay_1  delay_2  delay_3
# 0         10045               KLM     23.0     47.0      NaN
# 1         10055     Air France 12      NaN      NaN      NaN
# 2         10065  British Airways      24.0     43.0     87.0
# 3         10075     12 Air France     13.0      NaN      NaN
# 4         10085         Swiss Air     67.0     32.0      NaN
# <ipython-input-188-1d9e9972afb4>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   delays = df['RecentDelays'].apply(pd.Series)

# %% [markdown]
# Natija quyidagi ko'rinishda bo'lishi kerak:
# ```
#    FlightNumber          Airline      From         To  delay_1  delay_2  delay_3
# 0         10045              KLM    London      Paris     23.0     47.0      NaN
# 1         10055       Air France    Madrid      Milan      NaN      NaN      NaN
# 2         10065  British Airways    London  Stockholm     24.0     43.0     87.0
# 3         10075       Air France  Budapest      Paris     13.0      NaN      NaN
# 4         10085        Swiss Air  Brussels     London     67.0     32.0      NaN
# ```

# %% [markdown]
# ##`📌Minesweeper`
#
#
# ### Minesweeper tarmog'ida xavfsiz kvadratlar uchun raqamlar yaratamiz!
#
# 💡 Agar siz Windowsning avvalgi versiyalaridan foydalangan bo'lsangiz, Minesweeper bilan tanishsiz:
# - https://en.wikipedia.org/wiki/Minesweeper_(video_game)

# %% [markdown]
# Agar siz o'yin bilan tanish bo'lmasangiz, kvadratchalar to'plamini tasavvur qiling: bu kvadratlarning ba'zilari mineni yashiradi. Agar siz mineni bossangiz, darhol yo'qotasiz. Agar siz xavfsiz kvadratni bossangiz, darhol qo'shni bo'lgan kvadratchalarda qancha mine borligini ko'rsatadigan raqamni ko'rasiz. O'yinning maqsadi to'rdagi mine bo'lmagan barcha kvadratlarni ochishdir.
#
# Ushbu bo'limda biz Minesweeper o'yini uchun kerakli ma'lumotlarni o'z ichiga olgan DataFrame yaratamiz: kvadratlarning koordinatalari, kvadratda mine bormi va qo'shni kvadratlarda topilgan minelar sonini aniqlaymiz!

# %% [markdown]
# **35**. Tasavvur qiling, biz Minesweeper o'yinini 5 dan 4 gacha bo'lgan panjarada o'ynayapmiz, ya'ni.
# ```
# X = 5
# Y = 4
# ```
# Boshlash uchun ikkita ustunli DataFrame `df` yarating, bu tarmoq uchun har bir koordinatani o'z ichiga olgan `'x'` va `'y'`. Ya'ni DataFrame ishga tushishi kerak:
# ```
#     x y
# 0 0 0
# 1 0 1
# 2 0 2
# ```

# %% [markdown]
# **36**. Ushbu DataFrame `df` uchun yangi nol (safe) va birliklar (mine) ustunini yarating. Har bir joyda mine sodir bo'lish ehtimoli 0,4 bo'lishi kerak.

# %%
X = 5
Y = 4

coordinates = [(x, y) for x in range(X) for y in range(Y)]
df = pd.DataFrame(coordinates, columns=['x', 'y'])

df['value'] = np.random.choice([0, 1], size=len(df), p=[0.6, 0.4])

print(df)
# Out:
#     x  y  value
# 0   0  0      1
# 1   0  1      1
# 2   0  2      0
# 3   0  3      0
# 4   1  0      0
# 5   1  1      1
# 6   1  2      0
# 7   1  3      0
# 8   2  0      0
# 9   2  1      1
# 10  2  2      0
# 11  2  3      1
# 12  3  0      0
# 13  3  1      1
# 14  3  2      1
# 15  3  3      0
# 16  4  0      1
# 17  4  1      0
# 18  4  2      0
# 19  4  3      0

# %% [markdown]
# **37**. Endi ushbu DataFrame uchun `adjacent` nomli yangi ustun yarating. Ushbu ustunda tarmoqdagi qo'shni kvadratlarda topilgan minelar soni bo'lishi kerak.
#
# (Masalan, `(0, 0)` koordinatasi uchun yozuv bo'lgan birinchi qator uchun `(0, 1)`, `(1, 0)` va `(1) koordinatalarida qancha mine borligini hisoblang. , 1)`.)

# %%
def count_adjacent_mines(x, y, df):
    adjacent_mines = 0
    for dx in [-1, 0, 1]:
        for dy in [-1, 0, 1]:
            if (dx != 0 or dy != 0) and (x + dx >= 0 and x + dx < X) and (y + dy >= 0 and y + dy < Y):
                adjacent_mines += df.loc[(df['x'] == x + dx) & (df['y'] == y + dy), 'value'].values[0]
    return adjacent_mines

# Adjacent ustunini DataFrame'ga qo'shish
df['adjacent'] = df.apply(lambda row: count_adjacent_mines(row['x'], row['y'], df), axis=1)

print(df)
# Out:
#     x  y  value  adjacent
# 0   0  0      1         2
# 1   0  1      1         2
# 2   0  2      0         2
# 3   0  3      0         0
# 4   1  0      0         4
# 5   1  1      1         3
# 6   1  2      0         4
# 7   1  3      0         1
# 8   2  0      0         3
# 9   2  1      1         3
# 10  2  2      0         5
# 11  2  3      1         1
# 12  3  0      0         3
# 13  3  1      1         3
# 14  3  2      1         3
# 15  3  3      0         2
# 16  4  0      1         1
# 17  4  1      0         3
# 18  4  2      0         2
# 19  4  3      0         1

# %% [markdown]
# **38**. Mineni o'z ichiga olgan DataFrame qatorlari uchun `adjacent` ustunidagi qiymatni `NaN` ga o'zgartiring.

# %%
df.loc[df['value'] == 1, 'adjacent'] = np.nan
df
# Out:
#     x  y  value  adjacent
# 0   0  0      1       NaN
# 1   0  1      1       NaN
# 2   0  2      0       2.0
# 3   0  3      0       0.0
# 4   1  0      0       4.0
# 5   1  1      1       NaN
# 6   1  2      0       4.0
# 7   1  3      0       1.0
# 8   2  0      0       3.0
# 9   2  1      1       NaN
# 10  2  2      0       5.0
# 11  2  3      1       NaN
# 12  3  0      0       3.0
# 13  3  1      1       NaN
# 14  3  2      1       NaN
# 15  3  3      0       2.0
# 16  4  0      1       NaN
# 17  4  1      0       3.0
# 18  4  2      0       2.0
# 19  4  3      0       1.0

# %% [markdown]
# **39**. DataFrame-ni `adjacent` minelar sonining panjarasiga aylantiring: ustunlar `x` koordinatasi, qatorlar `y` koordinatasi.

# %%
df.set_index('y', inplace=True)
# Out:
#    x  value  adjacent
# y
# 0  0      1       NaN
# 1  0      1       NaN
# 2  0      0       2.0
# 3  0      0       0.0
# 0  1      0       4.0
# 1  1      1       NaN
# 2  1      0       4.0
# 3  1      0       1.0
# 0  2      0       3.0
# 1  2      1       NaN
# 2  2      0       5.0
# 3  2      1       NaN
# 0  3      0       3.0
# 1  3      1       NaN
# 2  3      1       NaN
# 3  3      0       2.0
# 0  4      1       NaN
# 1  4      0       3.0
# 2  4      0       2.0
# 3  4      0       1.0

# %%
df
# Out:
#    x  value  adjacent
# y
# 0  0      1       NaN
# 1  0      1       NaN
# 2  0      0       2.0
# 3  0      0       0.0
# 0  1      0       4.0
# 1  1      1       NaN
# 2  1      0       4.0
# 3  1      0       1.0
# 0  2      0       3.0
# 1  2      1       NaN
# 2  2      0       5.0
# 3  2      1       NaN
# 0  3      0       3.0
# 1  3      1       NaN
# 2  3      1       NaN
# 3  3      0       2.0
# 0  4      1       NaN
# 1  4      0       3.0
# 2  4      0       2.0
# 3  4      0       1.0

# %% [markdown]
# ##📌BONUS!
#
# O'zingiz javob berishni istagan savolni kiriting va unga javob bering!

# %% [markdown]
# Quyidagi Python kodida, foydalanuvchidan X va Y o'lchamlarni o'zgartirishga ruxsat berib, tekisliklikda joylashgan, foydalanuvchi tomonidan kiritilgan kenglik va balandlik miqdorlariga asosan kvadrat shaklini chizishni taqdim eting. Shuningdek, bu kvadratning har bir qator uchun ko'laygi (`x`, `y`) qiymatlari va minelar sonini hisoblash uchun adjacent ustunlarini hisoblaydigan funksiyalarni qo'llang.
# (***Savolni ChatGPT berdi***)

# %%
import matplotlib.pyplot as plt

def count_adjacent_mines(x, y, df):
    adjacent_mines = 0
    for dx in [-1, 0, 1]:
        for dy in [-1, 0, 1]:
            if (dx != 0 or dy != 0) and (x + dx >= 0 and x + dx < X) and (y + dy >= 0 and y + dy < Y):
                adjacent_mines += df.loc[(df['x'] == x + dx) & (df['y'] == y + dy), 'value'].values[0]
    return adjacent_mines

# Foydalanuvchidan kenglik va balandlik miqdorlarini so'raymiz
X = int(input("Kenglik miqdorini kiriting: "))
Y = int(input("Balandlik miqdorini kiriting: "))

# DataFrame df uchun koordinatlar
coordinates = [(x, y) for x in range(X) for y in range(Y)]
df = pd.DataFrame(coordinates, columns=['x', 'y'])

# Yangi nol va birliklar ustunlarini yaratish
df['value'] = np.random.choice([0, 1], size=len(df), p=[0.6, 0.4])

# Adjacent ustunini DataFrame'ga qo'shish
df['adjacent'] = df.apply(lambda row: count_adjacent_mines(row['x'], row['y'], df), axis=1)

# Mineni o'z ichiga olgan qatorlar uchun adjacent ustunidagi qiymatni NaN ga o'zgartirish
df.loc[df['value'] == 1, 'adjacent'] = np.nan

# Kvadrat shaklini chizish
def draw_square(X, Y):
    square = plt.Rectangle((0, 0), X, Y, linewidth=1, edgecolor='b', facecolor='none')
    fig, ax = plt.subplots()
    ax.add_patch(square)
    ax.set_aspect('equal', 'box')
    plt.xlim(0, X)
    plt.ylim(0, Y)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.grid(True)
    plt.show()

# Kvadratni chizish
draw_square(X, Y)

# Natijalarni chiqarish
print(df)
# Out:
# Kenglik miqdorini kiriting: 3
# Balandlik miqdorini kiriting: 3
#    x  y  value  adjacent
# 0  0  0      0       1.0
# 1  0  1      0       1.0
# 2  0  2      0       1.0
# 3  1  0      0       1.0
# 4  1  1      1       NaN
# 5  1  2      0       1.0
# 6  2  0      0       1.0
# 7  2  1      0       1.0
# 8  2  2      0       1.0
